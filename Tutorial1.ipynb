# %% [markdown]
# ### Tutorial 1

# %% [markdown]
# Question 1

# %%
from IPython.display import Image
# Question 1(a)
Image(filename=r"C:\Users\user\Downloads\photo_2025-12-01_14-56-37.jpg", width=250)

# %%
# Question 1(b)
Image(filename=r"C:\Users\user\Downloads\photo_2025-12-01_15-09-05.jpg", width=300)

# %%
import numpy as np
x_bin = np.base_repr(1234, 2)
x_oct = np.base_repr(1234, 8)
x_hexa = np.base_repr(1234, 16)

print(x_bin)
print(x_oct)
print(x_hexa)
# Out:
# 10011010010
# 2322
# 4D2

# %%
import numpy as np
x_bin = np.base_repr(-8970, 2)
x_oct = np.base_repr(-8970, 8)
x_hexa = np.base_repr(-8970, 16)

print(f"binary:{x_bin}")
print(f"octal:{x_oct}")
print(f"hexadecimal:{x_hexa}")
# Out:
# binary:-10001100001010
# octal:-21412
# hexadecimal:-230A

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 1000)

plt.figure(figsize=(4, 3))

plt.plot(x, np.sin(x), color='b', label="sin(x)")
plt.plot(x, np.cos(x), color="g", label="cos(x)")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Plot of sin(x) and cos(x) over [0,2$\pi$]")
plt.legend()
plt.grid()
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\p'
# <>:13: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\user\AppData\Local\Temp\ipykernel_11756\3687573404.py:13: SyntaxWarning: invalid escape sequence '\p'
#   plt.title("Plot of sin(x) and cos(x) over [0,2$\pi$]")

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from L4_NewtonRaphson.ipynb import newton
#
# ModuleNotFoundError: No module named 'L4_NewtonRaphson'
